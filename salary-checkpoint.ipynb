# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import scipy.stats as stats
import pylab
import random as random

# %%
data_set= pd.read_csv("salary_dataset\DatasetSalary.csv")
df=data_set.copy()   # veri setinin kopyasını aldık
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 data_set= pd.read_csv("DatasetSalary.csv")
#       2 df=data_set.copy()   # veri setinin kopyasını aldık
#
# ...

# %%
df.shape #veri setimiz 16534 satır ve 11 sütundan/özellikten meydana gelmekte)
# Out:
# (16534, 11)

# %%
df.head()
# Out:
#    work_year experience_level employment_type                  job_title  \
# 0       2024               SE              FT                AI Engineer
# 1       2024               SE              FT                AI Engineer
# 2       2024               SE              FT              Data Engineer
# 3       2024               SE              FT              Data Engineer
# 4       2024               SE              FT  Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0  202730             USD         202730                 US             0
# 1   92118             USD          92118                 US             0
# 2  130500             USD         130500                 US             0
# 3   96000             USD          96000                 US             0
# 4  190000             USD         190000                 US             0
#
#   company_location company_size
# 0               US            M
# ...

# %%
df.info() #veri tiplerini gördük ve null değer olup olmadığına baktık
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16534 entries, 0 to 16533
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           16534 non-null  int64
#  1   experience_level    16534 non-null  object
#  2   employment_type     16534 non-null  object
#  3   job_title           16534 non-null  object
#  4   salary              16534 non-null  int64
#  5   salary_currency     16534 non-null  object
#  6   salary_in_usd       16534 non-null  int64
#  7   employee_residence  16534 non-null  object
#  8   remote_ratio        16534 non-null  int64
#  9   company_location    16534 non-null  object
#  10  company_size        16534 non-null  object
# dtypes: int64(4), object(7)
# memory usage: 1.4+ MB

# %%
df.dtypes
df.experience_level=pd.Categorical(df.experience_level)
df.employment_type=pd.Categorical(df.employment_type)
df.job_title=pd.Categorical(df.job_title)
df.salary_currency=pd.Categorical(df.salary_currency)
df.employee_residence=pd.Categorical(df.employee_residence)
df.company_location=pd.Categorical(df.company_location)
df.company_size=pd.Categorical(df.company_size)

#bunu yapma sebebimiz object olan değişkenleri kategoriğe çevirmek. böylece veri setimiz daha hızlı ve efektif olabilecek.
#ml algoritmalarında kullanılırsa bu açıdan da kolaylık yaratacak.

# %%
df.describe().T
# Out:
#                  count           mean            std      min       25%  \
# work_year      16534.0    2023.226866       0.713558   2020.0    2023.0
# salary         16534.0  163726.962683  340205.744183  14000.0  101763.0
# salary_in_usd  16534.0  149686.777973   68505.293156  15000.0  101125.0
# remote_ratio   16534.0      32.003750      46.245158      0.0       0.0
#
#                     50%       75%         max
# work_year        2023.0    2024.0      2024.0
# salary         142200.0  187200.0  30400000.0
# salary_in_usd  141300.0  185900.0    800000.0
# remote_ratio        0.0     100.0       100.0

# %%
np.random.seed(15)
olcumler= np.random.randint(5,25,100)
orneklem=olcumler[0:20]
orneklem
# Out:
# array([13, 17, 10,  5, 12, 16, 20, 22, 18,  5, 15, 20,  9, 14, 12, 10, 24,
#        17, 18, 20])

# %%
stats.probplot(orneklem,dist ="norm",plot=pylab)
plab.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[237], line 2
#       1 stats.probplot(orneklem,dist ="norm",plot=pylab)
# ----> 2 plab.show()
#
# NameError: name 'plab' is not defined

# %%
df.isnull().values.any()
# Out:
# False

# %%
df["experience_level"].value_counts() #Dört çeşit deneyim tipine yer verdiklerini burada görüyoruz, veriler çoğunlukla senior ağırlıklı
#bu da veri setinin daha yüksek bir maaş ortalaması getirmesine sebep olacak
# Out:
# experience_level
# SE    10670
# MI     4038
# EN     1325
# EX      501
# Name: count, dtype: int64

# %%
df["experience_level"].value_counts().count()
# Out:
# 4

# %%
(df["experience_level"]
 .value_counts()
 .plot.barh());

# %%
(df["company_size"]
.value_counts()
.plot.barh()); #kişilerin çalıştıkları şirketler çoğunlukla orta ölçekli şirketler

# %%
df["employment_type"].value_counts() #verinin çok büyük bir çoğunluğu full-time çalışanlara ait
# Out:
# employment_type
# FT    16454
# PT       38
# CT       28
# FL       14
# Name: count, dtype: int64

# %%
df["salary_currency"].value_counts() #çok büyük bir çoğunluğu usd olsa bile farklı birimler veriyi yanlış etkileyebilir
#bu verileri dönüştürmek düşünülebilir
# Out:
# salary_currency
# USD    15294
# GBP      616
# EUR      449
# CAD       56
# INR       55
# AUD       12
# CHF        8
# PLN        7
# SGD        6
# BRL        5
# DKK        4
# JPY        4
# HUF        3
# TRY        3
# THB        2
# NOK        2
# ILS        2
# PHP        1
# NZD        1
# CLP        1
# MXN        1
# HKD        1
# ZAR        1
# Name: count, dtype: int64

# %%
kat_df = df.select_dtypes(include = "category")  #kategorik değişenlerin hepsini grupladık
kat_df.head()
# Out:
#   experience_level employment_type                  job_title salary_currency  \
# 0               SE              FT                AI Engineer             USD
# 1               SE              FT                AI Engineer             USD
# 2               SE              FT              Data Engineer             USD
# 3               SE              FT              Data Engineer             USD
# 4               SE              FT  Machine Learning Engineer             USD
#
#   employee_residence company_location company_size
# 0                 US               US            M
# 1                 US               US            M
# 2                 US               US            M
# 3                 US               US            M
# 4                 US               US            M

# %%
df_num = df.select_dtypes(include = ["float64","int64"]) #numerik değerlerin tamamını tek bir değişkene toparladık
df_num.head()
# Out:
#    work_year  salary  salary_in_usd  remote_ratio
# 0       2024  202730         202730             0
# 1       2024   92118          92118             0
# 2       2024  130500         130500             0
# 3       2024   96000          96000             0
# 4       2024  190000         190000             0

# %%
df_num["salary_in_usd"].describe()
# Out:
# count     16534.000000
# mean     149686.777973
# std       68505.293156
# min       15000.000000
# 25%      101125.000000
# 50%      141300.000000
# 75%      185900.000000
# max      800000.000000
# Name: salary_in_usd, dtype: float64

# %%
print("ortalama: " + str(df_num["salary_in_usd"].mean()))
print("dolu gözlem sayısı: " + str(df_num["salary_in_usd"].count()))
print("max değer: " + str(df_num["salary_in_usd"].max()))
print("min değer: " + str(df_num["salary_in_usd"].min()))
print("medyan: " + str(df_num["salary_in_usd"].median()))
print("standart sapma: " + str(df_num["salary_in_usd"].std()))
# Out:
# ortalama: 149686.77797266238
# dolu gözlem sayısı: 16534
# max değer: 800000
# min değer: 15000
# medyan: 141300.0
# standart sapma: 68505.2931563438

# %%
from pandas.api.types import CategoricalDtype

# %%
df.experience_level[0]= "EN"
df.experience_level[1]= "MI"
df.experience_level[2]= "SE"
df.experience_level[3]= "EX"

# %%
ordered_experience = CategoricalDtype(categories = ["EN", "MI", "SE", "EX"], ordered=True)

# %%
df.experience_level = df.experience_level.astype(ordered_experience)

# %%
df.experience_level.head()
# Out:
# 0    EN
# 1    MI
# 2    SE
# 3    EX
# 4    SE
# Name: experience_level, dtype: category
# Categories (4, object): ['EN' < 'MI' < 'SE' < 'EX']

# %%
(df["experience_level"]
.value_counts()
.plot.barh()
.set_title("Deneyim Seviyesi Dağılımı"));

# %%
sns.barplot( x = df.experience_level.value_counts().index, y=df.experience_level.value_counts(), data=df)
# Out:
# C:\Users\meebe\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <Axes: xlabel='experience_level', ylabel='count'>

# %%
df.head()
# Out:
#    work_year experience_level employment_type                  job_title  \
# 0       2024               EN              FT                AI Engineer
# 1       2024               MI              FT                AI Engineer
# 2       2024               SE              FT              Data Engineer
# 3       2024               EX              FT              Data Engineer
# 4       2024               SE              FT  Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0  202730             USD         202730                 US             0
# 1   92118             USD          92118                 US             0
# 2  130500             USD         130500                 US             0
# 3   96000             USD          96000                 US             0
# 4  190000             USD         190000                 US             0
#
#   company_location company_size
# 0               US            M
# ...

# %%
kat_df.head()
# Out:
#   experience_level employment_type                  job_title salary_currency  \
# 0               SE              FT                AI Engineer             USD
# 1               SE              FT                AI Engineer             USD
# 2               SE              FT              Data Engineer             USD
# 3               SE              FT              Data Engineer             USD
# 4               SE              FT  Machine Learning Engineer             USD
#
#   employee_residence company_location company_size
# 0                 US               US            M
# 1                 US               US            M
# 2                 US               US            M
# 3                 US               US            M
# 4                 US               US            M

# %%
sns.catplot(x = "experience_level", y = "salary_in_usd", data = df); 
#entry seviyesinde görüldüğü gibi 400000 üzerini gören bir değer dışında;(aykırı değer) değer yokken mid ve senior seviyelerinde bu sınır aşılmış. Nokta yoğunluğu yine de 400.000 seviyesinin altında olduğu kadar yoğun değil
#Bu duruma bakarak seviyelerin normalinin 400.000 üstü olmadığını anlasak da bu rakamların aşılması imkansız değildir.
# Out:
# C:\Users\meebe\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\meebe\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.catplot(x = "experience_level", y = "salary_in_usd", hue="work_year" ,data = df)
#400.000 sınırını geçen tüm değerlerin 2024'te verildiğini de ayrıca aklımızda tutmalıyız.
#önceki senelerde bu kadar yüksek maaşlar söz konusu değilmiş.
# Out:
# C:\Users\meebe\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\meebe\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df.groupby(["experience_level","work_year"])["salary_in_usd"].mean()
# Out:
# C:\Users\meebe\AppData\Local\Temp\ipykernel_13656\4111399907.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(["experience_level","work_year"])["salary_in_usd"].mean()
# experience_level  work_year
# EN                2020          69840.666667
#                   2021          63463.065217
#                   2022          80018.698276
#                   2023          91166.310345
#                   2024          98037.203240
# MI                2020          91870.935484
#                   2021          86818.390805
#                   2022         102745.576602
#                   2023         123821.311772
#                   2024         134780.872156
# SE                2020         138648.894737
#                   2021         125989.746667
# ...

# %%
sns.barplot(x = "remote_ratio", y = "salary_in_usd", hue="experience_level",data = df);

# %%
df.groupby(["experience_level","remote_ratio"])["salary_in_usd"].mean() 
#bu veriye göre hibrit çalışanlar seviye fark etmeksizin tamamen uzaktan veya tam zamanlı çalışan kişilerden daha düşük alıyorlar.
# Out:
# C:\Users\meebe\AppData\Local\Temp\ipykernel_13656\4138965406.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(["experience_level","remote_ratio"])["salary_in_usd"].mean()
# experience_level  remote_ratio
# EN                0                98872.122286
#                   50               62307.562500
#                   100              83662.644205
# MI                0               132341.487279
#                   50               76883.979167
#                   100             113802.741240
# SE                0               166555.857384
#                   50              108927.296875
#                   100             158836.554320
# EX                0               188039.255521
#                   50              147368.666667
# ...

# %%
#Aynı zamanda bu kişilerin başlangıç maaşları da diğer kişilere göre daha düşük 
sns.catplot(x = "experience_level", y = "salary_in_usd", hue = "remote_ratio", kind = "point", data = df);
# Out:
# C:\Users\meebe\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# C:\Users\meebe\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# ...

# %%
df["remote_ratio"].value_counts()
#fakat burada anlıyoruz ki bu kişilere dair veri sayısı çok az yorum yapmak çok da doğru olmayabilir.
# Out:
# remote_ratio
# 0      11118
# 100     5167
# 50       249
# Name: count, dtype: int64

# %%
sns.kdeplot(df.salary_in_usd,
           shade= True);
# Out:
# C:\Users\meebe\AppData\Local\Temp\ipykernel_13656\2811876790.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df.salary_in_usd,
# C:\Users\meebe\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
(sns
.FacetGrid(df,
           hue = "experience_level",
           height = 10,
           xlim = (0,400000))
.map(sns.kdeplot, "salary_in_usd", shade = True)
.add_legend()
);
# Out:
# C:\Users\meebe\anaconda3\Lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\meebe\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\meebe\anaconda3\Lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# ...

# %%
sns.catplot(x = "experience_level", y = "salary_in_usd", hue = "remote_ratio", kind = "point", data = df);
# Out:
# C:\Users\meebe\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# C:\Users\meebe\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# ...

# %%
df.head()
# Out:
#    work_year experience_level employment_type                  job_title  \
# 0       2024               EN              FT                AI Engineer
# 1       2024               MI              FT                AI Engineer
# 2       2024               SE              FT              Data Engineer
# 3       2024               EX              FT              Data Engineer
# 4       2024               SE              FT  Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0  202730             USD         202730                 US             0
# 1   92118             USD          92118                 US             0
# 2  130500             USD         130500                 US             0
# 3   96000             USD          96000                 US             0
# 4  190000             USD         190000                 US             0
#
#   company_location company_size
# 0               US            M
# ...

# %%
sns.boxplot( x = "company_size", y = "salary_in_usd" ,hue ="experience_level", data = df)
# Out:
# C:\Users\meebe\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <Axes: xlabel='company_size', ylabel='salary_in_usd'>

# %%
sns.pairplot(df,hue="company_size");
# Out:
# C:\Users\meebe\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\meebe\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1057: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_data = data.groupby(
# C:\Users\meebe\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...
